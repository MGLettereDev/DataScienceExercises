# %% [markdown]
# # Deep Learning

# %% [markdown]
# - Mathias Lettere
# - 09-11-2023

# %% [markdown]
# ## Importación de los datos

# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %% [markdown]
# ## Exploración de los datos

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %%
from tensorflow import keras
from tensorflow.keras import layers
model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])

# %% [markdown]
# ## Optimizador y función de pérdida

# %%
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ## Preprocesamiento

# %%
train_images=train_images.reshape((60000, 28*28))
train_images=train_images.astype("float32")/255

test_images=test_images.reshape((10000, 28*28))
test_images=test_images.astype("float32")/255

# %% [markdown]
# ## Entrenamiento

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 7s 14ms/step - loss: 2.2385 - accuracy: 0.2517
# Epoch 2/5
# 469/469 [==============================] - 5s 12ms/step - loss: 1.6840 - accuracy: 0.5920
# Epoch 3/5
# 469/469 [==============================] - 7s 14ms/step - loss: 1.0481 - accuracy: 0.7482
# Epoch 4/5
# 469/469 [==============================] - 5s 12ms/step - loss: 0.7489 - accuracy: 0.8113
# Epoch 5/5
# 469/469 [==============================] - 6s 13ms/step - loss: 0.6039 - accuracy: 0.8411

# %% [markdown]
# ## Predicción

# %%
test_digits=test_images[0:10]
predictions=model.predict(test_digits)
predictions[0]
# Out:
# 1/1 [==============================] - 0s 90ms/step
# array([0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.99999994, 0.        , 0.        ],
#       dtype=float32)

# %%
predictions[0].argmax()
# Out:
# 7

# %%
predictions[0][7]
# Out:
# 0.99999994

# %% [markdown]
# ### Etiqueta de evaluación

# %%
test_labels[0]
# Out:
# 7

# %% [markdown]
# ## Evaluación de la precisión

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 49.3021 - accuracy: 0.7302

# %% [markdown]
# # Representación de Datos para NN (con tensores)

# %%
#Escalar (tensor rango 0)
import numpy as np
x=np.array(12)
x
# Out:
# array(12)

# %%
x.ndim
# Out:
# 0

# %%
#Vectores (tenso rango 1)
x=np.array([2,3,4,5,7,15])
x
# Out:
# array([ 2,  3,  4,  5,  7, 15])

# %%
x.ndim
# Out:
# 1

# %%
#Matrices (tenso rango 2)
x=np.array([[5,78,2,34,0],
            [6,79,3,35,1],
            [7,80,4,36,2]])
x
# Out:
# array([[ 5, 78,  2, 34,  0],
#        [ 6, 79,  3, 35,  1],
#        [ 7, 80,  4, 36,  2]])

# %%
x.ndim
# Out:
# 2

# %%
#Tensores rango 3 y más
x = np.array([[[5, 78, 2, 34, 0],
[6, 79, 3, 35, 1],
[7, 80, 4, 36, 2]],
[[5, 78, 2, 34, 0],
[6, 79, 3, 35, 1],
[7, 80, 4, 36, 2]],
[[5, 78, 2, 34, 0],
[6, 79, 3, 35, 1],
[7, 80, 4, 36, 2]]])
x
# Out:
# array([[[ 5, 78,  2, 34,  0],
#         [ 6, 79,  3, 35,  1],
#         [ 7, 80,  4, 36,  2]],
#
#        [[ 5, 78,  2, 34,  0],
#         [ 6, 79,  3, 35,  1],
#         [ 7, 80,  4, 36,  2]],
#
#        [[ 5, 78,  2, 34,  0],
#         [ 6, 79,  3, 35,  1],
#         [ 7, 80,  4, 36,  2]]])

# %%
x.ndim
# Out:
# 3
